# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.stattools import adfuller
import pmdarima as pm
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
file_path = r"E:\file_main\Major_1\fauna-forecast\data\raw\bison_population_interpolated.csv"
df = pd.read_csv(file_path)

# Convert Year to datetime and set as index
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df.set_index('Year', inplace=True)

# Ensure yearly frequency
df = df.asfreq('YS')  # Year Start frequency

print(df.head())
# Out:
#               Population
# Year
# 1800-01-01  6.000000e+07
# 1801-01-01  5.933333e+07
# 1802-01-01  5.866667e+07
# 1803-01-01  5.800000e+07
# 1804-01-01  5.733333e+07

# %%
# Log-transform to handle large range
df['Log_Pop'] = np.log1p(df['Population'])

# Drop any missing values
series = df['Log_Pop'].dropna()
print(series.head())
print("Series length:", len(series))
# Out:
# Year
# 1800-01-01    17.909855
# 1801-01-01    17.898682
# 1802-01-01    17.887382
# 1803-01-01    17.875954
# 1804-01-01    17.864393
# Freq: YS-JAN, Name: Log_Pop, dtype: float64
# Series length: 218

# %%
result = adfuller(series.diff().dropna())  # first-order differencing
print("ADF Statistic:", result[0])
print("p-value:", result[1])

if result[1] <= 0.05:
    print("Series is stationary after 1st differencing")
else:
    print("Series is non-stationary – consider 2nd differencing")
# Out:
# ADF Statistic: -7.868687763099847
# p-value: 5.0531657830262255e-12
# Series is stationary after 1st differencing

# %%
# Auto ARIMA to choose best p, d, q
model_auto = pm.auto_arima(series,
                           start_p=0, max_p=5,
                           start_q=0, max_q=5,
                           d=1,  # use first-order differencing only
                           seasonal=False,
                           stepwise=True,
                           suppress_warnings=True,
                           trace=True)

p, d, q = model_auto.order
print(f"Chosen ARIMA order: p={p}, d={d}, q={q}")

# Fit ARIMA with chosen order
model = ARIMA(series, order=(p,d,q))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=139.535, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=126.949, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=129.971, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=138.499, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=125.814, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=126.527, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=123.752, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=122.445, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=123.768, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=128.290, Time=0.12 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=125.160, Time=0.59 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=120.646, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=128.666, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=125.514, Time=0.03 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=121.926, Time=0.10 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=121.943, Time=0.10 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=126.864, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=124.254, Time=0.04 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=123.351, Time=0.21 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 2.275 seconds
# Chosen ARIMA order: p=1, d=1, q=1
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Log_Pop   No. Observations:                  218
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -57.323
# Date:                Sat, 27 Sep 2025   AIC                            120.646
# Time:                        02:55:07   BIC                            130.786
# Sample:                    01-01-1800   HQIC                           124.742
#                          - 01-01-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8622      0.097      8.863      0.000       0.672       1.053
# ma.L1         -0.6993      0.118     -5.926      0.000      -0.931      -0.468
# sigma2         0.0992      0.002     49.866      0.000       0.095       0.103
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):            181600.97
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.38   Skew:                           -10.49
# Prob(H) (two-sided):                  0.00   Kurtosis:                       143.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast next 10 years
forecast_steps = 10
forecast_log = model_fit.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(start=series.index[-1] + pd.DateOffset(years=1),
                               periods=forecast_steps, freq='YS')

# Convert back from log
forecast_pop = np.expm1(forecast_log.predicted_mean)

# Create DataFrame
forecast_df = pd.DataFrame({
    'Forecast_Log': forecast_log.predicted_mean,
    'Forecast_Pop': forecast_pop
}, index=forecast_index)

print(forecast_df)
# Out:
#             Forecast_Log   Forecast_Pop
# 2018-01-01     13.159901  519124.315883
# 2019-01-01     13.192265  536200.338230
# 2020-01-01     13.220171  551374.273495
# 2021-01-01     13.244233  564802.172460
# 2022-01-01     13.264980  576642.515263
# 2023-01-01     13.282868  587050.838636
# 2024-01-01     13.298293  596176.031264
# 2025-01-01     13.311593  604157.947244
# 2026-01-01     13.323060  611126.029893
# 2027-01-01     13.332948  617198.687031

# %%
# Historical data
historical = df['Population']

# Forecasted data
forecast_index = pd.date_range(start='2018-01-01', end='2027-01-01', freq='YS')
forecast_pop = [519124.17, 536200.02, 551373.76, 564801.45, 576641.58, 
                587049.69, 596174.66, 604156.37, 611124.25, 617196.72]

# --- Plot ---
fig, axes = plt.subplots(2, 1, figsize=(12,10), sharey=False)

# Panel 1: Full history
axes[0].plot(historical.index, historical.values, label='Historical Population', color='blue')
axes[0].plot(forecast_index, forecast_pop, label='Forecasted Population', color='orange', linestyle='--', marker='o')
axes[0].set_title('Bison Population: Full History (1800–2027)')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Population')
axes[0].legend()
axes[0].grid(True)

# Panel 2: Zoom into modern recovery + forecast with auto y-scaling
axes[1].plot(historical.index, historical.values, label='Historical Population', color='blue')
axes[1].plot(forecast_index, forecast_pop, label='Forecasted Population', color='orange', linestyle='--', marker='o')
axes[1].set_xlim(pd.to_datetime("1900-01-01"), pd.to_datetime("2030-01-01"))

# Auto-adjust y-axis to show only modern range
modern_data = historical[historical.index >= "1900-01-01"]
y_min = 0
y_max = max(modern_data.max(), max(forecast_pop)) * 1.1  # add 10% padding
axes[1].set_ylim(y_min, y_max)

axes[1].set_title('Bison Population: Modern Recovery + Forecast (1900–2027)')
axes[1].set_xlabel('Year')
axes[1].set_ylabel('Population')
axes[1].legend()
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
# Train: until 2010 | Test: 2011–2017
train = df.loc[:'2010-12-31', 'Log_Pop']
test = df.loc['2011-12-31':'2017-12-31', 'Log_Pop']

print("Train size:", len(train))
print("Test size:", len(test))
# Out:
# Train size: 211
# Test size: 6

# %%
# Fit ARIMA with best order from auto_arima
best_order = model_auto.order
model = ARIMA(train, order=best_order)
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                Log_Pop   No. Observations:                  211
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -58.910
# Date:                Sat, 27 Sep 2025   AIC                            123.821
# Time:                        02:55:23   BIC                            133.862
# Sample:                    01-01-1800   HQIC                           127.880
#                          - 01-01-2010
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8599      0.102      8.418      0.000       0.660       1.060
# ma.L1         -0.6965      0.124     -5.635      0.000      -0.939      -0.454
# sigma2         0.1025      0.002     48.246      0.000       0.098       0.107
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.29   Jarque-Bera (JB):            164535.62
# Prob(Q):                              0.59   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.72   Skew:                           -10.32
# Prob(H) (two-sided):                  0.00   Kurtosis:                       138.57
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast for test length
forecast_log = model_fit.forecast(steps=len(test))

# Back-transform
forecast_pop = np.expm1(forecast_log)
test_pop = np.expm1(test)

# Combine results
forecast_df = pd.DataFrame({
    "Actual_Log": test,
    "Forecast_Log": forecast_log,
    "Actual_Pop": test_pop,
    "Forecast_Pop": forecast_pop
}, index=test.index)

forecast_df.head()

plt.figure(figsize=(10,5))
plt.plot(test_pop, label='Actual Population', marker='o')
plt.plot(forecast_pop, label='Forecasted Population', marker='x')
plt.title("ARIMA Forecast vs Actual (Test Set)")
plt.xlabel("Year")
plt.ylabel("Population")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Drop NaNs from both arrays
test_pop = test_pop.dropna()
forecast_pop = forecast_pop.dropna()

# Align lengths (in case one shrinks more than the other)
min_len = min(len(test_pop), len(forecast_pop))
test_pop = test_pop[:min_len]
forecast_pop = forecast_pop[:min_len]

mae = mean_absolute_error(test_pop, forecast_pop)
rmse = np.sqrt(mean_squared_error(test_pop, forecast_pop))
mape = np.mean(np.abs((test_pop - forecast_pop) / test_pop)) * 100

print("Evaluation Metrics:")
print("MAE :", mae)
print("RMSE:", rmse)
print("MAPE:", mape, "%")
# Out:
# Evaluation Metrics:
# MAE : 57265.19025499492
# RMSE: 60235.509963507575
# MAPE: 7.958496606065035 %
